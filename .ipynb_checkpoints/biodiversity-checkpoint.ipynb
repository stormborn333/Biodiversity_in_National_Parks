# %% [markdown]
# # Biodiversity in National Parks

# %% [markdown]
# Files `observations.csv` and `species info` contain data about 4 National Parks in United States. The goal of this project was analyze these files and find out wich Park is the best in terms of observation of differenet species. Before starting i knew that this data didn't contain null values.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df1 = pd.read_csv('observations.csv')
df1.head()
# Out:
#             scientific_name                            park_name  observations
# 0        Vicia benghalensis  Great Smoky Mountains National Park            68
# 1            Neovison vison  Great Smoky Mountains National Park            77
# 2         Prunus subcordata               Yosemite National Park           138
# 3      Abutilon theophrasti                  Bryce National Park            84
# 4  Githopsis specularioides  Great Smoky Mountains National Park            85

# %%
df2 = pd.read_csv('species_info.csv')
df2.head()
# Out:
#   category                scientific_name  \
# 0   Mammal  Clethrionomys gapperi gapperi
# 1   Mammal                      Bos bison
# 2   Mammal                     Bos taurus
# 3   Mammal                     Ovis aries
# 4   Mammal                 Cervus elaphus
#
#                                         common_names conservation_status
# 0                           Gapper's Red-Backed Vole                 NaN
# 1                              American Bison, Bison                 NaN
# 2  Aurochs, Aurochs, Domestic Cattle (Feral), Dom...                 NaN
# 3  Domestic Sheep, Mouflon, Red Sheep, Sheep (Feral)                 NaN
# 4                                      Wapiti Or Elk                 NaN

# %%
df = pd.merge(df1,df2) #merging two dataframes into one
df.head()
# Out:
#       scientific_name                            park_name  observations  \
# 0  Vicia benghalensis  Great Smoky Mountains National Park            68
# 1  Vicia benghalensis               Yosemite National Park           148
# 2  Vicia benghalensis            Yellowstone National Park           247
# 3  Vicia benghalensis                  Bryce National Park           104
# 4      Neovison vison  Great Smoky Mountains National Park            77
#
#          category                        common_names conservation_status
# 0  Vascular Plant  Purple Vetch, Reddish Tufted Vetch                 NaN
# 1  Vascular Plant  Purple Vetch, Reddish Tufted Vetch                 NaN
# 2  Vascular Plant  Purple Vetch, Reddish Tufted Vetch                 NaN
# 3  Vascular Plant  Purple Vetch, Reddish Tufted Vetch                 NaN
# 4          Mammal                       American Mink                 NaN

# %%
obs_sum = df.groupby(df['park_name']).sum().reset_index()
obs_sum.head()
# Out:
#                              park_name  observations
# 0                  Bryce National Park        633291
# 1  Great Smoky Mountains National Park        474863
# 2            Yellowstone National Park       1587641
# 3               Yosemite National Park        949452

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_style("whitegrid")
ax = plt.subplot()
sns.barplot(data = obs_sum, x='park_name', y='observations', palette = 'pastel')
plt.xlabel('Park name')
plt.ylabel('Observations in 10k')
plt.title('Total number of observations (in 10k)')
plt.show()

# %%
obs_mean = df.groupby(df['park_name']).mean().reset_index()
obs_mean
# Out:
#                              park_name  observations
# 0                  Bryce National Park     98.828184
# 1  Great Smoky Mountains National Park     74.104713
# 2            Yellowstone National Park    247.759207
# 3               Yosemite National Park    148.166667

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_style("whitegrid")
ax = plt.subplot()
sns.barplot(data = obs_mean, x='park_name', y='observations', palette = 'deep')
plt.xlabel('Park name')
plt.ylabel('Mean of observations')
plt.title('Average value of observations per Park')
plt.show()

# %%
x = df['category'].value_counts().reset_index()
x
# Out:
#                index  category
# 0     Vascular Plant     19560
# 1               Bird      2364
# 2  Nonvascular Plant      1332
# 3             Mammal      1200
# 4               Fish       524
# 5          Amphibian       328
# 6            Reptile       324

# %%
by_category = df.groupby(df['category']).sum().reset_index()
by_category
# Out:
#             category  observations
# 0          Amphibian         45068
# 1               Bird        332371
# 2               Fish         72901
# 3             Mammal        163120
# 4  Nonvascular Plant        190653
# 5            Reptile         45822
# 6     Vascular Plant       2795312

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_style("whitegrid")
ax = plt.subplot()
sns.barplot(data = df, x='park_name', y='observations', hue ='category' ,palette = 'deep')
plt.title('Average value of observations per park')
plt.show()

# %% [markdown]
# Data contains many different categories of species so I decided to divide analysis into two parts: for animals and plant.

# %% [markdown]
# ## Animals

# %%
df_animals = df[(df['category']=='Mammal') |(df['category']=='Bird') | 
                (df['category']=='Amphibian') | (df['category']=='Reptile') | 
                (df['category']=='Fish') ] #creating df containing only data about animals
df_animals.head()
# Out:
#      scientific_name                            park_name  observations  \
# 4     Neovison vison  Great Smoky Mountains National Park            77
# 5     Neovison vison            Yellowstone National Park           218
# 6     Neovison vison                  Bryce National Park            91
# 7     Neovison vison               Yosemite National Park           200
# 24  Spizella pusilla            Yellowstone National Park           228
#
#    category   common_names conservation_status
# 4    Mammal  American Mink                 NaN
# 5    Mammal  American Mink                 NaN
# 6    Mammal  American Mink                 NaN
# 7    Mammal  American Mink                 NaN
# 24     Bird  Field Sparrow                 NaN

# %%
sns.barplot(data = df_animals, x='park_name', y='observations', palette = 'deep', 
      order = ['Yellowstone National Park','Yosemite National Park', 'Bryce National Park', 'Great Smoky Mountains National Park'])
plt.title('Average value of animal observations per park')
plt.show()

# %% [markdown]
# It's easy to see that Yellowstone park have the biggest mean of animal observations. It's very possible that is this park we have highest chance to see animals and more of them.
# In the code below I created 4 data frames, each for one park. In this data frames we have values of animals observations ordered from the highest to the lowest. It can be helpful in checking wihch species are most common and wich one are the rarest in the park.

# %%
df_animals_yellowstone = df_animals[df_animals.park_name == 'Yellowstone National Park'].sort_values(by='observations', ascending = False)
df_animals_yellowstone.head()
# Out:
#               scientific_name                  park_name  observations  \
# 22194  Chrysemys picta bellii  Yellowstone National Park           307
# 2484         Spinus lawrencei  Yellowstone National Park           305
# 16446        Aythya americana  Yellowstone National Park           304
# 20629        Ambystoma opacum  Yellowstone National Park           301
# 6085            Perdix perdix  Yellowstone National Park           300
#
#         category                    common_names conservation_status
# 22194    Reptile          Western Painted Turtle                 NaN
# 2484        Bird            Lawrence's Goldfinch                 NaN
# 16446       Bird                         Redhead                 NaN
# 20629  Amphibian              Marbled Salamander                 NaN
# 6085        Bird  Gray Partridge, Grey Partridge                 NaN

# %%
df_animals_yosemite = df_animals[df_animals.park_name == 'Yosemite National Park'].sort_values(by='observations', ascending = False)
df_animals_yosemite.head()
# Out:
#                      scientific_name               park_name  observations  \
# 12450               Calidris canutus  Yosemite National Park           207
# 8405   Hypsiglena torquata nuchalata  Yosemite National Park           204
# 24810                 Cervus elaphus  Yosemite National Park           203
# 24811                 Cervus elaphus  Yosemite National Park           203
# 16693         Etheostoma blennioides  Yosemite National Park           203
#
#       category           common_names conservation_status
# 12450     Bird               Red Knot                 NaN
# 8405   Reptile  California Nightsnake                 NaN
# 24810   Mammal          Wapiti Or Elk                 NaN
# 24811   Mammal     Rocky Mountain Elk                 NaN
# 16693     Fish       Greenside Darter                 NaN

# %%
df_animals_bryce = df_animals[df_animals.park_name == 'Bryce National Park'].sort_values(by='observations', ascending = False)
df_animals_bryce.head()
# Out:
#            scientific_name            park_name  observations category  \
# 20716     Martes americana  Bryce National Park           167   Mammal
# 20717     Martes americana  Bryce National Park           167   Mammal
# 19010        Bubulcus ibis  Bryce National Park           164     Bird
# 13167  Nyctanassa violacea  Bryce National Park           160     Bird
# 18528   Certhia familiaris  Bryce National Park           158     Bird
#
#                              common_names conservation_status
# 20716                         Pine Marten                 NaN
# 20717             American Marten, Marten                 NaN
# 19010  Cattle Egret, Western Cattle Egret                 NaN
# 13167          Yellow-Crowned Night-Heron                 NaN
# 18528                Eurasian Treecreeper                 NaN

# %%
df_animals_gsm = df_animals[df_animals.park_name == 'Great Smoky Mountains National Park'].sort_values(by='observations', ascending = False)
df_animals_gsm.head()
# Out:
#              scientific_name                            park_name  \
# 15374      Branta hutchinsii  Great Smoky Mountains National Park
# 22885       Lepomis gibbosus  Great Smoky Mountains National Park
# 4040   Notropis rubricroceus  Great Smoky Mountains National Park
# 3735       Lasiurus borealis  Great Smoky Mountains National Park
# 8381       Poecile rufescens  Great Smoky Mountains National Park
#
#        observations category               common_names conservation_status
# 15374           139     Bird             Cackling Goose                 NaN
# 22885           133     Fish                Pumpkinseed                 NaN
# 4040            131     Fish             Saffron Shiner                 NaN
# 3735            127   Mammal   Eastern Red Bat, Red Bat                 NaN
# 8381            126     Bird  Chestnut-Backed Chickadee                 NaN

# %% [markdown]
# ## Plants

# %%
df_plants = df[(df['category']=='Vascular Plant') | 
               (df['category']=='Nonvascular PLant')] #creating df containg only data about plants
df_plants.head()
# Out:
#       scientific_name                            park_name  observations  \
# 0  Vicia benghalensis  Great Smoky Mountains National Park            68
# 1  Vicia benghalensis               Yosemite National Park           148
# 2  Vicia benghalensis            Yellowstone National Park           247
# 3  Vicia benghalensis                  Bryce National Park           104
# 8   Prunus subcordata               Yosemite National Park           138
#
#          category                        common_names conservation_status
# 0  Vascular Plant  Purple Vetch, Reddish Tufted Vetch                 NaN
# 1  Vascular Plant  Purple Vetch, Reddish Tufted Vetch                 NaN
# 2  Vascular Plant  Purple Vetch, Reddish Tufted Vetch                 NaN
# 3  Vascular Plant  Purple Vetch, Reddish Tufted Vetch                 NaN
# 8  Vascular Plant                        Klamath Plum                 NaN

# %%
sns.barplot(data = df_plants, x='park_name', y='observations', palette = 'deep', 
            order = ['Yellowstone National Park','Yosemite National Park', 'Bryce National Park', 'Great Smoky Mountains National Park'])
plt.title('Average value of plant observations per Park')
plt.show()

# %% [markdown]
# Again Yellowstone Park have the highest mean of observations, this time plant observations. The rest of the parks seems to have very similiar results. I once created data frames ordered by number of observations, these below contains data about plants.

# %%
df_plants_yellowstone = df_plants[df_plants.park_name == "Yellowstone National Park"].sort_values(by="observations",ascending = False)
df_plants_yellowstone.head()
# Out:
#                  scientific_name                  park_name  observations  \
# 11629     Lycopodium tristachyum  Yellowstone National Park           321
# 5512          Castilleja miniata  Yellowstone National Park           317
# 22240  Dracocephalum parviflorum  Yellowstone National Park           316
# 3375         Cryptantha fendleri  Yellowstone National Park           316
# 20347          Bidens tripartita  Yellowstone National Park           314
#
#              category                                       common_names  \
# 11629  Vascular Plant                   Deep-Root Clubmoss, Ground Cedar
# 5512   Vascular Plant  Giant Red Indian Paintbrush, Great Red Indian ...
# 22240  Vascular Plant                                American Dragonhead
# 3375   Vascular Plant  Fendler's Cryptantha, Sanddune Catseye, Sanddu...
# 20347  Vascular Plant      Threelobe Beggarticks, Three-Lobe Beggarticks
#
#       conservation_status
# 11629                 NaN
# 5512                  NaN
# 22240                 NaN
# 3375                  NaN
# 20347                 NaN

# %%
df_plants_yosemite = df_plants[df_plants.park_name == "Yosemite National Park"].sort_values(by="observations",ascending = False)
df_plants_yosemite.head()
# Out:
#                           scientific_name               park_name  \
# 14193     Ivesia shockleyi var. shockleyi  Yosemite National Park
# 16978                Lipocarpha micrantha  Yosemite National Park
# 7308                     Trillium rugelii  Yosemite National Park
# 17739  Artemisia arbuscula ssp. arbuscula  Yosemite National Park
# 10267               Castilleja pallescens  Yosemite National Park
#
#        observations        category  \
# 14193           223  Vascular Plant
# 16978           222  Vascular Plant
# 7308            219  Vascular Plant
# 17739           219  Vascular Plant
# 10267           214  Vascular Plant
#
#                                             common_names conservation_status
# 14193                   Shockley's Ivesia, Sky Mousetail                 NaN
# 16978  Dwarf Bulrush, Smallflower Halfchaff Sedge, Sm...                 NaN
# 7308                           Southern Nodding Trillium                 NaN
# 17739               Gray Low Sagebrush, Little Sagebrush                 NaN
# 10267            Pale Indian Paintbrush, Pale Paintbrush                 NaN

# %%
df_plants_bryce = df_plants[df_plants.park_name == "Bryce National Park"].sort_values(by="observations",ascending = False)
df_plants_bryce.head()
# Out:
#             scientific_name            park_name  observations  \
# 17121  Valerianella radiata  Bryce National Park           176
# 16155      Melilotus indica  Bryce National Park           173
# 23525   Ericameria bloomeri  Bryce National Park           172
# 1737      Draba oligosperma  Bryce National Park           167
# 12940          Avena sativa  Bryce National Park           163
#
#              category                      common_names conservation_status
# 17121  Vascular Plant     Beaked Corn-Salad, Corn Salad                 NaN
# 16155  Vascular Plant                        Sourclover                 NaN
# 23525  Vascular Plant  Bloomer's Goldenbush, Rabbitbush                 NaN
# 1737   Vascular Plant      Fewseed Draba, Glacier Draba                 NaN
# 12940  Vascular Plant              Cultivated Oat, Oats                 NaN

# %%
df_plants_gsm = df_plants[df_plants.park_name == "Great Smoky Mountains National Park"].sort_values(by="observations",ascending = False)
df_plants_gsm.head()
# Out:
#                 scientific_name                            park_name  \
# 22356  Sonchus asper ssp. asper  Great Smoky Mountains National Park
# 17522        Lespedeza violacea  Great Smoky Mountains National Park
# 15647      Botrychium dissectum  Great Smoky Mountains National Park
# 9354           Festuca subulata  Great Smoky Mountains National Park
# 24495       Castilleja cusickii  Great Smoky Mountains National Park
#
#        observations        category  \
# 22356           147  Vascular Plant
# 17522           146  Vascular Plant
# 15647           144  Vascular Plant
# 9354            141  Vascular Plant
# 24495           135  Vascular Plant
#
#                                           common_names conservation_status
# 22356                                 Spiny Sowthistle                 NaN
# 17522                               Violet Bush-Clover                 NaN
# 15647        Cutleaf Grape-Fern, Cut-Leaved Grape Fern                 NaN
# 9354                    Bearded Fescue, Nodding Fescue                 NaN
# 24495  Cusick's Indian Paintbrush, Cusick's Paintbrush                 NaN

# %% [markdown]
# At the end I wanted to check conservation status of the species. Plots below do not containt NaN values. I focused only on known status.

# %%
df.conservation_status.unique()
# Out:
# array([nan, 'Species of Concern', 'Threatened', 'Endangered',
#        'In Recovery'], dtype=object)

# %%
df_status = df.dropna()
df_status.conservation_status.unique()
# Out:
# array(['Species of Concern', 'Threatened', 'Endangered', 'In Recovery'],
#       dtype=object)

# %%
k = df_status.conservation_status.value_counts().reset_index()
labels = ['Species of Concern', 'Endangere','Threatened','In Recovery']
plt.pie(k.conservation_status, labels = labels, autopct='%1.2f%%')
plt.axis('equal')
plt.title('Coservation status of all species')
plt.show()

# %%
df_animals_status = df_animals.dropna()
k = df_animals_status.conservation_status.value_counts().reset_index()
labels = ['Species of Concern', 'Endangere','Threatened','In Recovery']
plt.pie(k.conservation_status, labels = labels, autopct='%1.2f%%')
plt.title('Conservation status of animals')
plt.show()

# %%
df_plants_status = df_plants.dropna()
k = df_plants_status.conservation_status.value_counts().reset_index()
labels = ['Species of Concern', 'Threatened', 'Endangered']
plt.pie(k.conservation_status, labels = labels, autopct='%1.2f%%')
plt.title('Conservation status of plants')
plt.show()
